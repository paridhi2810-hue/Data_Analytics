# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("/content/i1.csv")
df2 = pd.read_csv("/content/i2.csv")

# %%
df = df1.merge(df2,how='outer')

# %%
df.shape
# Out:
# (15621, 16)

# %%
df.isna().sum()
# Out:
# Date               0
# Timestamp          0
# Invoice No.        0
# Item Name          0
# Price              0
# Qty.               0
# Sub Total          0
# Discount           0
# Tax                0
# Final Total        0
# Table No.          8
# Server Name        0
# Covers             0
# Variation      15606
# Category           0
# HSN            15621
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15621 entries, 0 to 15620
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         15621 non-null  object
#  1   Timestamp    15621 non-null  object
#  2   Invoice No.  15621 non-null  int64
#  3   Item Name    15621 non-null  object
#  4   Price        15621 non-null  float64
#  5   Qty.         15621 non-null  float64
#  6   Sub Total    15621 non-null  float64
#  7   Discount     15621 non-null  float64
#  8   Tax          15621 non-null  float64
#  9   Final Total  15621 non-null  float64
#  10  Table No.    15613 non-null  float64
#  11  Server Name  15621 non-null  object
#  12  Covers       15621 non-null  int64
#  13  Variation    15 non-null     object
#  14  Category     15621 non-null  object
#  15  HSN          0 non-null      float64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#         Invoice No.         Price          Qty.     Sub Total      Discount  \
# count  15621.000000  15621.000000  15621.000000  15621.000000  15621.000000
# mean   25989.963127    116.608988      1.338839    147.407080      1.262818
# std     1433.192998     63.663769      0.949814    210.127442      6.656396
# min    23465.000000     12.000000      1.000000     12.000000      0.000000
# 25%    24751.000000     50.000000      1.000000     80.000000      0.000000
# 50%    25980.000000    140.000000      1.000000    150.000000      0.000000
# 75%    27274.000000    160.000000      1.000000    170.000000      0.000000
# max    28389.000000    770.000000     28.000000  21560.000000    288.000000
#
#                 Tax   Final Total     Table No.   Covers  HSN
# count  15621.000000  15621.000000  15613.000000  15621.0  0.0
# mean       7.303668    153.447930     18.068340      0.0  NaN
# std       10.461474    219.678163     17.191377      0.0  NaN
# ...

# %%
df.drop(['Table No.','Discount','Covers','HSN','Variation','Server Name'],axis=1)
# Out:
#              Date            Timestamp  Invoice No.  \
# 0      2023-04-01  2023-04-01 13:16:03        23465
# 1      2023-04-01  2023-04-01 13:16:03        23465
# 2      2023-04-01  2023-04-01 13:16:03        23465
# 3      2023-04-01  2023-04-01 13:16:03        23465
# 4      2023-04-01  2023-04-01 13:16:03        23465
# ...           ...                  ...          ...
# 15616  2023-09-19  2023-09-19 22:03:44        28389
# 15617  2023-09-19  2023-09-19 22:03:44        28389
# 15618  2023-09-19  2023-09-19 22:03:44        28389
# 15619  2023-09-19  2023-09-19 22:03:44        28389
# 15620  2023-09-19  2023-09-19 22:03:44        28389
#
#                          Item Name  Price  Qty.  Sub Total    Tax  \
# 0              Babycorn Manchurian  160.0   1.0      160.0   8.00
# 1                Chicken Kati Roll  120.0   1.0      120.0   6.00
# 2             Paneer Butter Masala  150.0   2.0      300.0  15.00
# 3                     Pulka (2 No)   40.0   3.0      120.0   6.00
# ...

# %%
total_amount = df['Final Total'].sum()
print(total_amount)
# Out:
# 2397010.12

# %%
df['Invoice No.'].nunique()
# Out:
# 4925

# %%
avg_value=total_amount/df['Invoice No.'].nunique()
print(avg_value)
# Out:
# 486.70256243654825

# %%
x=df.groupby('Item Name')['Qty.'].sum().sort_values(ascending=False)[0:5]
print(x)
# Out:
# Item Name
# Mineral Water                             1672.0
# Chicken Biriyani With Raitha And Gravy    1453.0
# Butter Naan                               1046.0
# Romali Roti (1 No)                         822.0
# Lemon Soda                                 722.0
# Name: Qty., dtype: float64

# %%
sns.barplot(x)
# Out:
# <Axes: xlabel='Item Name', ylabel='Qty.'>

# %%
x.plot(kind='bar')
# Out:
# <Axes: xlabel='Item Name'>

# %%
df.groupby('Item Name')['Final Total'].sum().sort_values(ascending=False)
# Out:
# Item Name
# Chicken Biriyani With Raitha And Gravy    240730.96
# Chicken Fried Rice                        119347.20
# Butter Naan                                65387.74
# Thandoor Chicken Half                      53185.83
# Paneer Butter Masala                       49581.22
#                                             ...
# Tomato Soup                                   84.00
# Veg Kothu Parata                              73.50
# Water Bottle 500 Ml                           63.00
# Vechhu Paratha (1 No)                         52.50
# Soft Drinks Tin                               42.00
# Name: Final Total, Length: 270, dtype: float64

# %%
y=df.groupby('Item Name')['Final Total'].sum().sort_values(ascending=False)[0:5]
y.plot(kind='bar')
# Out:
# <Axes: xlabel='Item Name'>

# %%
df['Date'].unique()
y=df.groupby('Date')['Final Total'].sum()
y.loc["2023-09-15"]
# Out:
# np.float64(21042.02)

# %%
df[(df['Date']=='2023-09-15')&(df['Item Name']=='Chicken Noodles')]['Qty.'].sum()
# Out:
# np.float64(7.0)

# %%
z=df.groupby('Invoice No.')['Final Total'].sum()
z[z==2887.50]
# Out:
# Invoice No.
# 28126    2887.5
# Name: Final Total, dtype: float64

# %%
df[df['Invoice No.']==28145]['Qty.'].sum()
# Out:
# np.float64(40.0)

# %%
df[df['Invoice No.']==28145]['Final Total'].sum()
# Out:
# np.float64(4078.68)

# %%
df[df['Invoice No.']==28145]['Item Name']
# Out:
# 14830                      Butter Chicken Gravy
# 14831                      Butter Chicken Gravy
# 14832                               Butter Naan
# 14833    Chicken Biriyani With Raitha And Gravy
# 14834                   Chicken Chettinad Gravy
# 14835                Chicken Pallipalayam Gravy
# 14836                                   Fish 65
# 14837                               Garlic Naan
# 14838                                  Gobi- 65
# 14839                              Kadai Paneer
# 14840                     Kozhi Milaghuperattal
# 14841                             Mineral Water
# 14842          Pepper Tandoori Chicken ( Full )
# 14843          Pepper Tandoori Chicken ( Half )
# 14844                        Romali Roti (1 No)
# 14845               Schewan  Chicken Fried Rice
# 14846                    Schewan Chicken Noodle
# 14847                      Schezwan Veg Noodles
# Name: Item Name, dtype: object

# %%
df.groupby('Invoice No.')['Item Name'].sum()
# Out:
# Invoice No.
# 23465    Babycorn ManchurianChicken Kati RollPaneer But...
# 23466    Chocolate Milk ShakeChocolate Milk ShakeMinera...
# 23467    Chicken Biriyani With Raitha And GravyFish 65M...
# 23468                    Plain Briyani With Raitha, Gravy.
# 23469    Chicken Biriyani With Raitha And GravyEgg Frie...
#                                ...
# 28385    Butter NaanChicken NoodlesMineral WaterPaneer ...
# 28386    Butter Chicken GravyButter NaanChicken Lolly P...
# 28387    Chicken 65Chicken 65 BonelessChicken Biriyani ...
# 28388    Chicken 65 BonelessChicken Biriyani With Raith...
# 28389    Gobi- 65KulchaMineral WaterMushroom MasalaPane...
# Name: Item Name, Length: 4925, dtype: object

# %%
from wordcloud import WordCloud
text = ' '.join(df['Item Name'].dropna().astype(str).values)
wordcloud = WordCloud(background_color='white',width=900,height=300).generate(text)
fig,ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation='bicubic')
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []
