# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/insurance_claims.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
df.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
# !pip install missingno
import missingno as msno
msno.bar(df)
# Out:
# ...
# <Axes: >

# %%
sns.heatmap(df.isnull(),cbar=True,cmap='viridis')
# Out:
# <Axes: >

# %%
from sklearn.impute import SimpleImputer

imp = SimpleImputer(strategy='most_frequent')

df[['authorities_contacted']] = imp.fit_transform(df[['authorities_contacted']])

df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.drop(['_c39'],axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

cat_cols = X.select_dtypes(include='object').columns

ct = ColumnTransformer([('onehot', OneHotEncoder(handle_unknown='ignore'),cat_cols)],remainder='passthrough')
X_encoded = ct.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(
      criterion='entropy',
    max_depth=5,
    random_state=42
)
model.fit(X_encoded, y)
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# ['N' 'N' 'N' 'N' 'N' 'N' 'Y' 'Y' 'N' 'N' 'N' 'N' 'N' 'Y' 'Y' 'N' 'N' 'Y'
#  'Y' 'Y' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'Y'
#  'N' 'N' 'N' 'N' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'N' 'N' 'N' 'N' 'N' 'N' 'Y' 'N'
#  'Y' 'Y' 'N' 'N' 'N' 'N' 'N' 'N' 'Y' 'N' 'N' 'N' 'N' 'N' 'Y' 'N' 'N' 'N'
#  'N' 'N' 'Y' 'N' 'Y' 'Y' 'N' 'Y' 'N' 'N' 'Y' 'N' 'N' 'N' 'N' 'Y' 'N' 'N'
#  'Y' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'Y' 'N' 'N' 'Y' 'N' 'N' 'Y' 'N' 'N' 'N'
#  'N' 'Y' 'N' 'Y' 'N' 'N' 'N' 'Y' 'Y' 'N' 'N' 'N' 'N' 'Y' 'Y' 'N' 'Y' 'N'
#  'N' 'Y' 'N' 'N' 'Y' 'N' 'N' 'N' 'Y' 'N' 'N' 'N' 'Y' 'N' 'N' 'Y' 'N' 'Y'
#  'N' 'N' 'N' 'N' 'N' 'Y' 'Y' 'N' 'Y' 'N' 'Y' 'Y' 'N' 'Y' 'Y' 'N' 'Y' 'Y'
#  'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'N' 'Y' 'Y' 'Y' 'N' 'N' 'N' 'Y' 'Y' 'Y' 'N' 'N'
#  'Y' 'N' 'N' 'Y' 'Y' 'N' 'N' 'Y' 'N' 'N' 'N' 'Y' 'N' 'N' 'Y' 'N' 'N' 'N'
#  'N' 'N']

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
from sklearn.metrics import confusion_matrix, classification_report

print(confusion_matrix(y_test, y_pred))

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.88
# [[127  18]
#  [  6  49]]
#               precision    recall  f1-score   support
#
#            N       0.95      0.88      0.91       145
#            Y       0.73      0.89      0.80        55
#
#     accuracy                           0.88       200
#    macro avg       0.84      0.88      0.86       200
# weighted avg       0.89      0.88      0.88       200

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(12,8))

plot_tree(model,feature_names=ct.get_feature_names_out(),class_names=['N','Y'],filled=True)

plt.show()
